# %%
import pandas as pd
import numpy as np
import os
import requests
import json
from datetime import datetime

# %%
# Create a list with all files in the folder using a list comprehension

folderpath = r"/Users/ru/City-Bike_Analysis/2022-citibike-tripdata" # make sure to put the 'r' in front
filepath = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]

# %%
filepath
# Out:
# ['/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202209-citibike-tripdata.zip',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202201-citibike-tripdata.zip',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/.DS_Store',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202203-citibike-tripdata.zip',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202205-citibike-tripdata.zip',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202207-citibike-tripdata.zip',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202211-citibike-tripdata.zip',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202201-citibike-tripdata 2',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202208-citibike-tripdata.zip',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202202-citibike-tripdata.zip',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202212-citibike-tripdata.zip',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202204-citibike-tripdata.zip',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202201-citibike-tripdata',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202210-citibike-tripdata.zip',
#  '/Users/ru/City-Bike_Analysis/2022-citibike-tripdata/202206-citibike-tripdata.zip']

# %%
import zipfile

# %%
dfs = []

for zip_file in filepath:
    if zip_file.endswith(".zip"):
        with zipfile.ZipFile(zip_file) as z:
            for name in z.namelist():
                if name.endswith(".csv"):
                    df_month = pd.read_csv(
                        z.open(name),
                        low_memory=False
                    )
                    dfs.append(df_month)

# %%
df = pd.concat(dfs, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.concat(dfs, ignore_index=True)
#
# File /opt/anaconda3/envs/venv_City-Bike_Analysis/lib/python3.14/site-packages/pandas/core/reshape/concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)    392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File /opt/anaconda3/envs/venv_City-Bike_Analysis/lib/python3.14/site-packages/pandas/core/reshape/concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File /opt/anaconda3/envs/venv_City-Bike_Analysis/lib/python3.14/site-packages/pandas/core/internals/concat.py:185, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     182     else:
#     183         values = concat_compat(vals, axis=1)
# --> 185     values = ensure_wrapped_if_datetimelike(values)
#     187     fastpath = blk.values.dtype == values.dtype
#     188 else:
#
# File /opt/anaconda3/envs/venv_City-Bike_Analysis/lib/python3.14/site-packages/pandas/core/construction.py:481, in ensure_wrapped_if_datetimelike(arr)
#     476         return obj.to_numpy()  # type: ignore[attr-defined]
#     478     return obj
# --> 481 def ensure_wrapped_if_datetimelike(arr):
#     482     """
#     483     Wrap datetime64 and timedelta64 ndarrays in DatetimeArray/TimedeltaArray.
#     484     """
#     485     if isinstance(arr, np.ndarray):
#
# KeyboardInterrupt:

# %%
df.shape

# %%
df.head()

# %%
df.tail()

# %%
Token = "xsUjVeQyODAucSZouRAbpkNiHoCoGMuw"

# %%
# Get the API 

r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00014732&startdate=2022-01-01&enddate=2022-12-31', headers={'token':Token})

# %%
# Load the api response as a json

d = json.loads(r.text)

# %%
d

# %%
# Secure all items in the response that correspond to TAVG

avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']

# %%
# Get only the date field from all average temperature readings

dates_temp = [item['date'] for item in avg_temps]

# %%
# Get the temperature from all average temperature readings

temps = [item['value'] for item in avg_temps]

# %%
temps

# %%
# Put the results in a dataframe

df_temp = pd.DataFrame()

# %%
# Get only date and cast it to date time; convert temperature from tenths of Celsius to normal Celsius

df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
df_temp['avgTemp'] = [float(v)/10.0 for v in temps]

# %%
type(df_temp['date'].iloc[0])

# %%
df_temp.tail()

# %%
df_temp.head()

# %%
df.dtypes

# %%
df.head(5)

# %%
df['started_at'] = pd.to_datetime(df['started_at'])

# %%
df['date'] = df['started_at'].dt.floor('D')

# %%
# %%time
df_merged = df.merge(df_temp, how = 'left', on = 'date', indicator = True)
